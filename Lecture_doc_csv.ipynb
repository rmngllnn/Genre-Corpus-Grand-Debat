# %%
import pandas as pd

# %%
#exemple = open('/Documents/hubic/Cours/M1_LI/Stage/DEMOCRATIE_ET_CITOYENNETE.csv', 'r')


df = pd.read_csv("../DEMOCRATIE_ET_CITOYENNETE.csv", low_memory = False)
df.shape

df.head(15)
# Out:
#    reference                                              title  \
# 0        1-2                 Les augmentations de rémunérations
# 1        1-3  rénover l'enquête publique pour en faire un vr...
# 2        1-4        Limitations de vitesse et sécurité routière
# 3        1-5                    Pour un nouveau contrat citoyen
# 4        1-6  Développer les démarches de budget participati...
# 5        1-7                                     proportienelle
# 6        1-8              Pour plus de démocratie participative
# 7        1-9                      Transparence de la vie public
# 8       1-11                18 mois de trop....ca suffit macron
# 9       1-12           Egalité devant les infractions routières
# 10      1-13    Mesures d'urgence pour une démocratie régénérée
# 11      1-14     SORTIR DU GRAND EST ! REOUR A LA REGION ALSACE
# 12      1-15                          Pour plus de transparence
# 13      1-16                          Ecoutez enfin le  peuple.
# 14      1-18                                   Vote obligatoire
#
#               createdAt          publishedAt            updatedAt  trashed  \
# 0   2019-01-22 09:38:41  2019-01-22 09:38:41                  NaN    False
# 1   2019-01-22 09:40:04  2019-01-22 09:40:04  2019-01-22 09:41:00    False
# 2   2019-01-22 09:44:04  2019-01-22 09:44:04                  NaN    False
# 3   2019-01-22 09:44:05  2019-01-22 09:44:05                  NaN    False
# 4   2019-01-22 09:45:18  2019-01-22 09:45:43                  NaN    False
# 5   2019-01-22 09:45:53  2019-01-22 09:45:53                  NaN    False
# 6   2019-01-22 09:47:09  2019-01-22 09:47:09                  NaN    False
# 7   2019-01-22 09:47:11  2019-01-22 09:54:49                  NaN    False
# 8   2019-01-22 09:48:17  2019-01-22 09:48:17                  NaN    False
# 9   2019-01-22 09:48:32  2019-01-22 09:48:32                  NaN    False
# 10  2019-01-22 09:49:45  2019-01-22 09:49:45                  NaN    False
# 11  2019-01-22 09:50:02  2019-01-23 09:33:25                  NaN    False
# 12  2019-01-22 09:51:05  2019-01-22 13:42:19                  NaN    False
# 13  2019-01-22 09:51:41  2019-01-22 09:51:41  2019-01-22 19:02:46    False
# 14  2019-01-22 09:53:26  2019-01-22 09:53:26                  NaN    False
#
#    trashedStatus                                           authorId  \
# 0            NaN  VXNlcjo4Mjc4NzQxYS0xZTFkLTExZTktOTRkMi1mYTE2M2...
# 1            NaN  VXNlcjo4OWQ3MzE5My0xZDYwLTExZTktOTRkMi1mYTE2M2...
# 2            NaN  VXNlcjowMzYyMTUyNy0xZDEyLTExZTktOTRkMi1mYTE2M2...
# 3            NaN  VXNlcjo4YWJlYzBmOS0xZGE3LTExZTktOTRkMi1mYTE2M2...
# 4            NaN  VXNlcjo2Nzc5MjE4OC0xZTIxLTExZTktOTRkMi1mYTE2M2...
# 5            NaN  VXNlcjpmYmNjODEwNS0xZDkyLTExZTktOTRkMi1mYTE2M2...
# 6            NaN  VXNlcjo5NmNhYWM4ZS0xZTIwLTExZTktOTRkMi1mYTE2M2...
# 7            NaN  VXNlcjo0ZTQxY2UxZi0xZTIxLTExZTktOTRkMi1mYTE2M2...
# 8            NaN  VXNlcjo4MjgzZTUyNi0xZDU5LTExZTktOTRkMi1mYTE2M2...
# 9            NaN  VXNlcjowMzYyMTUyNy0xZDEyLTExZTktOTRkMi1mYTE2M2...
# 10           NaN  VXNlcjpmNGRjNmQ0Yi0xZTFjLTExZTktOTRkMi1mYTE2M2...
# 11           NaN  VXNlcjo2MDMwZTk4YS0xZTIyLTExZTktOTRkMi1mYTE2M2...
# 12           NaN  VXNlcjo3Y2NmOWU4NS0xZTIyLTExZTktOTRkMi1mYTE2M2...
# 13           NaN  VXNlcjpkZTE5ZTMzZC0xOTgxLTExZTktOTRkMi1mYTE2M2...
# 14           NaN  VXNlcjoyMTVjMzgyNi0xZDA4LTExZTktOTRkMi1mYTE2M2...
#
#                    authorType  authorZipCode  ...  \
# 0         Citoyen / Citoyenne          79190  ...
# 1         Citoyen / Citoyenne           1800  ...
# 2         Citoyen / Citoyenne          44300  ...
# 3         Citoyen / Citoyenne          29490  ...
# 4         Citoyen / Citoyenne          94300  ...
# 5                         NaN          26400  ...
# 6         Citoyen / Citoyenne          27500  ...
# 7         Citoyen / Citoyenne          45000  ...
# 8         Citoyen / Citoyenne          13920  ...
# 9         Citoyen / Citoyenne          44300  ...
# 10  Élu / élue et Institution           6270  ...
# 11        Citoyen / Citoyenne          68000  ...
# 12        Citoyen / Citoyenne          78400  ...
# 13        Citoyen / Citoyenne          34740  ...
# 14        Citoyen / Citoyenne          75012  ...
#
#    Quel pourrait être le rôle de chacun pour faire reculer les incivilités dans la société ?  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  Chaque citoyen  peut effectivement sensibilise...
# 14                                                NaN
#
#    Quelles sont les discriminations les plus répandues dont vous êtes témoin ou victime ?  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  Une discrimination dont on ne parle jamais , l...
# 14                                                NaN
#
#    Que faudrait-il faire pour lutter contre ces discriminations et construire une société plus solidaire et plus tolérante ?  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                   dejà que l'état respecte LES LOIS
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  La tolérance ne pourra être que quand certaine...
# 14                                                NaN
#
#    Pensez-vous qu'il faille instaurer des contreparties aux différentes allocations de solidarité ?  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 Oui
# 9                                                 NaN
# 10                                                Oui
# 11                                                NaN
# 12                                                NaN
# 13                                                Oui
# 14                                                Oui
#
#                                  Si oui, lesquelles ?  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                 travail obligatoire
# 9                                                 NaN
# 10  Impôt obligatoire, quitte à ce qu'il soit de u...
# 11                                                NaN
# 12                                                NaN
# 13  Tout bénéficiaire du RSA doit compenser cette ...
# 14                                                NaN
#
#    Que pensez-vous de la situation de l'immigration en France aujourd'hui et de la politique migratoire ? Quelles sont, selon vous, les critères à mettre en place pour définir la politique migratoire ?  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   ca suffit de voir entrer en FRANCE ces gens , ...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  L'immigration en France a atteint un sommet qu...
# 14                                                NaN
#
#    En matière d'immigration, une fois nos obligations d'asile remplies, souhaitez-vous que nous puissions nous fixer des objectifs annuels définis par le Parlement ?  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8              OUI  mais pas 300000 comme actuellment
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  L'asile doit être temporaire et reconductible ...
# 14                                                NaN
#
#    Que proposez-vous afin de répondre à ce défi qui va durer ?  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   commencer par supprimer l'AME et interdire tou...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  La question est ambiguë car on parle de problè...
# 14                                                NaN
#
#    Quelles sont, selon vous, les modalités d'intégration les plus efficaces et les plus justes à mettre en place aujourd'hui dans la société ?  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8            aucune  ....retour direct hors frontière
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  Apprendre la langue et la culture du pays ains...
# 14                                                NaN
#
#    Y a-t-il d'autres points sur la démocratie et la citoyenneté sur lesquels vous souhaiteriez vous exprimer ?
# 0   Afin d’éviter de creuser les inégalités ne plu...
# 1                                                 NaN
# 2   Nous proposons le retour à la limitation de vi...
# 3   POUR UN NOUVEAU CONTRAT CITOYEN               ...
# 4                                                 NaN
# 5                                                 NaN
# 6   Développer la démocratie participative en comm...
# 7                                                 NaN
# 8   macron est un dictateur ce débat est du gros p...
# 9   Nous proposons de mettre fin à la tolérance po...
# 10                                                NaN
# 11                                                NaN
# 12  Il faut plus de transparence. Le MH370 a dispa...
# 13  La démocratie c'est aussi accepter la liberté ...
# 14                                                NaN
#
# [15 rows x 46 columns]
